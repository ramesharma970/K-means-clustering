# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to implement K-Means clustering
def kmeans(X, k, max_iters=100, tol=1e-4):
    # Randomly initialize centroids
    centroids = X[np.random.choice(X.shape[0], k, replace=False)]
    
    for _ in range(max_iters):
        # Step 1: Assign labels based on closest centroid
        distances = np.linalg.norm(X[:, np.newaxis] - centroids, axis=2)
        labels = np.argmin(distances, axis=1)
        
        # Step 2: Recompute centroids (mean of points in each cluster)
        new_centroids = np.array([X[labels == i].mean(axis=0) for i in range(k)])
        
        # Step 3: Check for convergence (centroid changes)
        if np.all(np.abs(new_centroids - centroids) < tol):
            break
        
        centroids = new_centroids
    
    return centroids, labels

# Generate some random data (for illustration)
np.random.seed(42)
X1 = np.random.randn(100, 2) + [3, 3]
X2 = np.random.randn(100, 2) + [-3, -3]
X3 = np.random.randn(100, 2) + [6, -6]
X = np.vstack([X1, X2, X3])

# Apply K-Means
k = 3
centroids, labels = kmeans(X, k)

# Plot the original data and the clustering result
plt.figure(figsize=(8, 6))

# %%
np.random.seed(42)
X1 = np.random.randn(100, 2) + [3, 3]
X2 = np.random.randn(100, 2) + [-3, -3]
X3 = np.random.randn(100, 2) + [6, -6]
X = np.vstack([X1, X2, X3])
print(X)
# Out:
# [[ 3.49671415  2.8617357 ]
#  [ 3.64768854  4.52302986]
#  [ 2.76584663  2.76586304]
#  [ 4.57921282  3.76743473]
#  [ 2.53052561  3.54256004]
#  [ 2.53658231  2.53427025]
#  [ 3.24196227  1.08671976]
#  [ 1.27508217  2.43771247]
#  [ 1.98716888  3.31424733]
#  [ 2.09197592  1.5876963 ]
#  [ 4.46564877  2.7742237 ]
#  [ 3.0675282   1.57525181]
#  [ 2.45561728  3.11092259]
#  [ 1.84900642  3.37569802]
#  [ 2.39936131  2.70830625]
#  [ 2.39829339  4.85227818]
#  [ 2.98650278  1.94228907]
#  [ 3.82254491  1.77915635]
#  [ 3.2088636   1.04032988]
#  [ 1.67181395  3.19686124]
#  [ 3.73846658  3.17136828]
#  [ 2.88435172  2.6988963 ]
#  [ 1.52147801  2.28015579]
#  [ 2.53936123  4.05712223]
#  [ 3.34361829  1.23695984]
#  [ 3.32408397  2.61491772]
#  [ 2.323078    3.61167629]
#  [ 4.03099952  3.93128012]
#  [ 2.16078248  2.69078762]
#  [ 3.33126343  3.97554513]
#  [ 2.52082576  2.81434102]
#  [ 1.89366503  1.80379338]
#  [ 3.81252582  4.35624003]
#  [ 2.92798988  4.0035329 ]
# ...

# %%
# Plot original data (before clustering)
plt.scatter(X[:, 0], X[:, 1], c='gray', marker='o', s=50, label='Original Data')

# %%
# Plot clustered data
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', s=50, label='Clustered Data')

# %%
# Plot centroids
plt.scatter(centroids[:, 0], centroids[:, 1], color='red', marker='x', s=200, label='Centroids')

# %%
# Plot clustered data
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', s=50, label='Clustered Data')

# Plot centroids
plt.scatter(centroids[:, 0], centroids[:, 1], color='red', marker='x', s=200, label='Centroids')

plt.title('K-Means Clustering (Original vs Clustered Data)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()
